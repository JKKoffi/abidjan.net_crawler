# %% [markdown]
# # Crawl Abidjan.net annonce by ID
#
# We'll use an ID to crawl and preprocess all of these annonce.

# %% [markdown]
# ## Imports  libraries

# %%
import time
import os
import numpy as np  
from datetime import datetime
import pandas as pd

import io
import requests
from string import punctuation
import locale
from datetime import datetime
import re
from bs4 import BeautifulSoup, SoupStrainer
import requests
import sys

# %% [markdown]
# ## Utility functions

# %%
def create_dir(dir_path):
  if not os.path.exists(dir_path):
    os.makedirs(dir_path)
  print("Done")

#mesure elapsed time
from contextlib import contextmanager
from timeit import default_timer
@contextmanager
def elapsed_timer():
    start = default_timer()
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start

# def save_history(df):
      
#       if not os.path.exists(path_to_history):
#         df.to_csv(path_to_history, header=True, encoding='utf-16le', index =False,mode='a')
#       else:
#         df1 = pd.read_csv(path_to_history, encoding='utf-16le')
#         df_full = pd.concat([df1, df],axis=0)
#         df_full = df_full.reset_index()
#         df_full = df_full.drop_duplicates()
#         df.to_csv(path_to_history, header=True, encoding='utf-16le', index =False,mode='a')


            
def search_links_id(start_id):

  pages = []
  j=start_id
  stop = False
  i = 0
  while stop ==False:

      url = f'https://business.abidjan.net/AL/a/{j}.asp'
      response = requests.get(url)
      if response.ok:
        pages.append(url)
        i = 0
      else:
        i +=1
        if i>50: #stop if more than 50 pages are failled
          stop=True
      j +=1
      # save_history(pd.DataFrame({'pages':url},index=[0]))
  df = pd.DataFrame({'pages':pages})
  return df


def elapsed_timer():
    start = default_timer()
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start



""" Crawle page data"""

import re
from bs4 import BeautifulSoup, SoupStrainer
import requests

def crawl_data(df_links):

  session = requests.Session()

  data = []
  mesure_complexity = {} # jsut to measure the execution time
  pages_fail = []

  N=df_links.shape[0]
  i = 0


  # with elapsed_timer() as elapsed:    
  # if i>4:
  #     time.sleep(20)
  for link in df_links.iloc[:,0].tolist():
    data1 = []
    download_url = link
    data1.append(download_url)
    try:
      response = session.get(download_url)
      try:
        soup = BeautifulSoup(response.text, 'html.parser')
        # elem = soup.find("div", {"id": "module"})
        # data1 = [
        #           download_url,
        #           elem.next_sibling.next_sibling.next_sibling.next_sibling.text,
        #           elem.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text
        #         ]
        elem = soup.findAll("div", {"id": "module"})
        data1 = [
                  download_url,
                  elem[0].text,elem[1].text,elem[2].text
                ]
        print(len(data1[2]))    
        data.append(data1)
        print(f'{download_url} done!')
      except:
        try:
          soup = BeautifulSoup(response.text, 'html.parser')
          # elem = soup.find("div", {"id": "shadow"})
          elem = soup.find("div", {"id": "page_content"})
          data1 = [download_url,elem.text]
          print(len(data1[1]))
          data.append(data1)
        except:
          print(f'failed on {download_url}')
          pages_fail.append(download_url)
    except:
        pages_fail.append(download_url)
    # time.sleep(5)
    i +=1
    prog = ((i+1)/N) * 100
    print('\rCompleted: {:.2f}%'.format(prog),end=' ')



  df_2 = pd.DataFrame({'link':[x[0] for x in data if len(x)==2], "content":[x[1] for x in data if len(x)==2]})
  df_3 = pd.DataFrame({'link':[x[0] for x in data if len(x)==4], "header":[x[2] for x in data if len(x)==4],"content":[x[3] for x in data if len(x)==4]})  
  df_fail = pd.DataFrame({'pages':pages_fail}) 
  df_fail.to_csv(os.path.join(dir_result,'pages_failed.csv'), header=True, encoding='utf-16le', index =False , sep=';',mode="a")

  df_3['page-content'] = df_3['header']+''+df_3['content']
  df_2['page-content'] = df_2['content']
  df_merged = pd.DataFrame()
  columns=['link', 'page-content']
  df_merged = pd.concat([df_2.loc[:,columns], df_3.loc[:,columns]], axis=0)
  df_merged = df_merged.reset_index()
  df_merged = df_merged.drop(['index'], axis = 1)

  return df_merged


import unicodedata


def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii.decode('utf-8')
# src:https://stackoverflow.com/questions/517923/what-is-the-best-way-to-remove-accents-normalize-in-a-python-unicode-string

from string import punctuation
def remove_punctuations(string):
	for pct in punctuation:
		string = string.replace(pct,' ')
		string = re.sub('\s\s+',' ',string)
	return string


def decode_encode(string):
  bytestring = string.encode('ascii', 'ignore').decode('ascii')#.encode('utf-8')
  return bytestring#.decode('utf-8')

#find email
def find_email(string):
  try:
    email_found = re.findall(r'[\w]*@[\w]*.[\w]*', string)
    if len(email_found)==1:
      return email_found[0]
    else:
      chr = ''
      for x in email_found:
        chr += '/'+ x
      return chr
  except:
    pass

#find capital
def find_capital(string):

  string = remove_punctuations(string)
  string = string.replace('FRANCS CFA','FCFA')
  # string = string.replace('F CFA', 'FCFA')
  string0 = string.replace(' ','')
  string0 = string0.replace('DE','')
  try:
    return float(re.findall(r'[0-9]{7,12}FCFA', string0)[0].replace('FCFA', ''))
  except:
    try:
      start = string.lower().find('capital')
      string1 = string1[start,start+15]
      return float(re.findall(r'[0-9]{7,12}', string0)[0].replace('FCFA', ''))
    except:
      pass

def find_tel(string):
  string = remove_accents(string).lower()
  start = string.find('tel')
  if start!=-1:
    string = string[start:]
    string = remove_punctuations(string)
    # string = string.replace('225','')
    stop = string.find('capital') 
    string = string[:stop]
    chr = ''
    string = string.replace(' ','')
    string = re.findall(r'[0-9]{8,8}', string)
    for x in string:
      chr += x+'|'
    return chr


  string = string
  string = remove_punctuations(string)
  # string = string.replace('225','')
  stop = string.find('fax') 
  string = string[:stop]
  chr = ''
  string = string.replace(' ','')
  string = re.findall(r'[0-9]{8,8}', string)
  for x in string:
    chr += x+'|'
  return chr


def find_fax(string):
  string = remove_accents(string).lower()
  start = string.find('fax')
  if start!=-1:
    string = string[start:]
    string = remove_punctuations(string)
    string = string.replace('225','')
    string = string[:20]
    chr = ''
    string = string.replace(' ','')
    string = re.findall(r'[0-9]{8,8}', string)
    for x in string:
      chr +=' '+x
    return chr

def find_notaire(string):
  start = string.lower().find('notaire')
  string = string[start:start+50]
  string0 =  re.findall(r'[A-Z]{2,20}',string)
  if len(string0)!=0:
    chr = ''
    for x in string0:
      chr += ' '+x
    return chr
  else:
    stop = string.find('date')
    string1 = string[:stop]
    start = string1.find(':')
    try:
      int(string1[start:])
    except:
      return string1[start:]


def find_cat(string):
  start = string.lower().find('catégorie')
  string = string[start:start+100]
  stop=string.lower().find('avocat')
  string = string[:stop-1]
  string0 =  re.findall(r'[A-Z]{2,20}',string)
  if len(string0)!=0:
    chr = ''
    for x in string0:
      chr += ' '+x
    return chr

def find_cat(string):
  start = remove_accents(string).lower().find('catégorie')
  if start!=-1:
    
    string = string[start:start+100]
    stop=string.lower().find('avocat')
    string = string[:stop-1]
    string0 =  re.findall(r'[A-Z]{2,20}',string)
    if len(string0)!=0:
      chr = ''
      for x in string0:
        chr += ' '+x
      return chr

  start = remove_accents(string).lower().find('catgorie')
  string = string[start:start+100]
  stop=string.lower().find('avocat')
  string = string[:stop-1]
  string0 =  re.findall(r'[A-Z]{2,20}',string)
  if len(string0)!=0:
    chr = ''
    for x in string0:
      chr += ' '+x
    return chr


def find_date(string):
  string = string.lower()
  start = string.lower().find('date de')
  if start!=-1:
    try:
      string = string[start:start+50]
      string = re.findall(r'[a-z]+ [0-9]{1,2} [a-z]+ [0-9]{4,4}',string)[0]
      return string
    except:
      pass






def find_rccm(string):
  string = string.lower()

  start = string.find('rccm')
  if start!=-1:
    try:
      string = string[start:start+100].replace(' ','') 
      string = re.findall(r'[a-z]*[a-z]*[0-9]{1,4}[a-z]{1,1}[0-9]{1,4}', remove_punctuations(string))
      string0 =  string[0].replace('rccm','') 
      stop = string0.find('ci')
      return string0[stop:]
    except:
      pass
  try:
    return re.findall(r'[a-z]*[a-z]*[0-9]{1,4}[a-z]{1,1}[0-9]{1,4}', remove_punctuations(string))
  except:
    pass


def remove_punctuations2(string):
  for pct in punctuation:
    string = string.replace(pct,' ')
    string = re.sub('\s\s+',' ',string)
  return string

def find_miss_rccm(string):
  string = string.encode('ascii', 'ignore').decode('ascii')
  string =  string.lower()
  string0 = re.findall(r'[a-z]* [a-z]* [a-z]*[0-9]{1,4} [a-z]{1,1} [0-9]{1,4}', remove_punctuations2(string))
  if len(string0)>0:
      return string0[0]
  string1 = re.findall(r'[a-z]*[a-z]*[0-9]{1,4}[a-z]{1,1} [0-9]{1,6}', remove_punctuations2(string))
  if len(string1)>0:
        return string1[0]

def find_missing_rccm(string):
  fields_list = [x for x in re.split('\n[^\w]*', string.split('\n\n\n')[-1]) if x not in [' ',''] and len(x)>2]
  for field in fields_list:
    field = remove_accents(field.lower())
    start = (remove_accents(field.lower())).find(remove_accents('rccm'.lower()))
    if start!=-1:
      return field[start+4:]

#BP
def find_bp(string):
  string = string.lower()
  start = remove_accents(string).find('siege')
  if start!=-1:
    matches = ['[0-9]{1,4} bp [0-9]{1,4} [a-z]* [0-9]{1,2}',r'[0-9]{1,4} bp [0-9]{1,4}',r'[0-9]{1,2} bp [0-9]{1,4} [a-z]* [0-9]{1,4}',r'bp [0-9]{1,4} [a-z]* [0-9]{1,4}',r'bp [0-9]{1,4} [a-z]* [0-9]{1,4}',r'[a-z]* bp [0-9]{1,4}',r'[a-z]* bp [0-9]{1,4}']

    for match in matches:
      # string = string[start:]#start+100]
      string0 = re.findall(match, string)
      if len(string0)!=0:
        chrt = ''
        for x in string0:
          chrt += x + "/"
        return chrt
  else:
    matches = [r'bp [a-z]+ [0-9]+',r'\[a-z]{2,15}',r'[0-9]{1,4} bp [0-9]{1,4} [a-z]* [0-9]{1,2}',r'[0-9]{1,4} bp [0-9]{1,4}',r'[0-9]{1,2} bp [0-9]{1,4} [a-z]* [0-9]{1,4}',r'bp [0-9]{1,4} [a-z]* [0-9]{1,4}',r'bp [0-9]{1,4} [a-z]* [0-9]{1,4}',r'[a-z]* bp [0-9]{1,4}',r'[a-z]* bp [0-9]{1,4}']

    for match in matches:
      # string = string[start:]#start+100]
      string0 = re.findall(match, string)
      if len(string0)!=0:
        chrt = ''
        for x in string0:
          chrt += x + "|"
        return chrt

# string = df_merged.loc[84084,'page-content']
def find_miss_bp(string):
  string = string.lower()
  start = string.find('bp')
  if start!=-1:
    string = string[start:]
    stop = string.find('\n')
    if stop!=-1:
      string = string[:stop]
      return re.sub('\s\s+','',remove_punctuations(string).replace('bp',''))#.find('\n')
        
def find_duree(string):
  start = (remove_accents(string).lower()).find('duree')
  if start!=-1:
      string0 = string[start+8:start+12]
      string0 = re.findall(r'[0-9]{2,2}',string0)
      if len(string0)==1:
        return string0[0]
      string1 = string[start:start+12]
      string1 = re.findall(r'[0-9]{2,2}',string1)
      return string1
      
    

      
def find_name(string):
  start = remove_accents(string).lower().find('societe')
  string = string[start+8:start+100]
  stop=remove_accents(string).lower().find('categorie')
  string = string[:stop-1]
  string0 =  re.findall(r'[A-Z]{2,20}',string)
  if len(string0)!=0:
    chr = ''
    for x in string0:
      chr += ' '+x
    return chr
  else:
    string0 =  re.findall(r'[A-Z]{1,20}',string)
    chr = ''
    for x in string0:
      chr += ' '+x
    return chr

def find_siege(string):
  string = remove_accents(string).lower() 
  start = string.find('siege')
  string = string[start:]
  stop = string.find('\n')
  string = string[:stop]
  string = string.replace('siege','')
  string = string.replace('social','')
  string = string.replace(':','')
  string = re.sub('\s\s+','',string)
  return string  



def search_fileds(df_merged):

  df_merged['content'] = df_merged['page-content'].apply(lambda x: ' '.join(x.split('\n')))

  df_merged['content'] = df_merged.content.apply(lambda string: decode_encode(string) )

  #replace multiple space by one
  df_merged['content'] = df_merged['content'].apply( lambda string: re.sub("\s\s+" , " ", string) )

  # df_merged['email'] = 
  df_merged['email'] = df_merged['content'].apply( lambda string: find_email( string) )

  # df_merged['email'] = 
  df_merged['capital'] = df_merged['content'].apply( lambda string: find_capital(string) )

  df_merged['tel'] = df_merged['content'].apply(lambda string: find_tel(string))

  df_merged['fax'] = df_merged['content'].apply(lambda string: find_fax(string))

  df_merged['notaire'] = df_merged['content'].apply(lambda string: find_notaire(string))

  df_merged['notaire'] = df_merged['content'].apply(lambda string: find_notaire(string))

  df_merged['categorie'] = df_merged['content'].apply(lambda string: find_cat(string))

  df_merged['nom'] = df_merged['content'].apply(lambda string: find_name(string))

  df_merged['date'] = df_merged['content'].apply(lambda string: find_date(string))

  df_merged['rccm'] = df_merged['content'].apply(lambda string: find_rccm(string))

  df_merged.loc[df_merged['rccm'].isna(),'rccm'] = df_merged.loc[df_merged['rccm'].isna(),'content'].apply(lambda x:find_miss_rccm(x))

  df_merged.loc[df_merged['rccm'].isna(),'rccm'] = df_merged.loc[df_merged['rccm'].isna(),'page-content'].apply(lambda x:find_missing_rccm(x))

  df_merged['bp'] = df_merged['content'].apply(lambda string: find_bp(string))

  df_merged.loc[df_merged['bp'].isna(),'bp'] = df_merged.loc[df_merged['bp'].isna(),'page-content'].apply(lambda x:find_miss_bp(x))

  df_merged['duree'] = df_merged['content'].apply(lambda string: find_duree(string))

  df_merged.loc[[i for i,x in enumerate(df_merged['content']) if x.lower().find('abidjan')!=-1],['ville']]='Abidjan'

  df_merged['siege'] = df_merged['page-content'].apply(lambda x: find_siege(x))

  df_merged.loc[[i for i,x in enumerate(df_merged['content']) if x.lower().find('abidjan')!=-1],['ville']]='Abidjan'

  return df_merged

# %% [markdown]
# ## Set up  dirs and csts, and local language

# %%
dir_result = 'results'
path_to_history = os.path.join(dir_result, 'history.csv')
create_dir(dir_result)
#set for french date
locale.setlocale(locale.LC_ALL)
# Out:
# Done
# 'LC_CTYPE=en_US.UTF-8;LC_NUMERIC=C;LC_TIME=C;LC_COLLATE=C;LC_MONETARY=C;LC_MESSAGES=C;LC_PAPER=C;LC_NAME=C;LC_ADDRESS=C;LC_TELEPHONE=C;LC_MEASUREMENT=C;LC_IDENTIFICATION=C'

# %% [markdown]
# ## Start search lin by ID
#
# * Search lins and save into a variable called `df_link`
#
# * Start Id set 94100.

# %%
df_links = search_links_id(94100)
df_links.head()
# Out:
#                                          pages
# 0  https://business.abidjan.net/AL/a/94100.asp
# 1  https://business.abidjan.net/AL/a/94101.asp
# 2  https://business.abidjan.net/AL/a/94102.asp
# 3  https://business.abidjan.net/AL/a/94103.asp
# 4  https://business.abidjan.net/AL/a/94104.asp

# %%
print('Number of links avalaible is:',df_links.shape[0])
# Out:
# Number of links avalaible is: 307

# %% [markdown]
# ## Start the crawler to grab content for each links found

# %%
df_merged = crawl_data(df_links)
df_merged.head()#will return the 5 rows of the df
# Out:
# 144
# https://business.abidjan.net/AL/a/94100.asp done!
# Completed: 0.65% 224
# https://business.abidjan.net/AL/a/94101.asp done!
# Completed: 0.98% 126
# https://business.abidjan.net/AL/a/94102.asp done!
# Completed: 1.31% 160
# https://business.abidjan.net/AL/a/94103.asp done!
# Completed: 1.63% 211
# https://business.abidjan.net/AL/a/94104.asp done!
# Completed: 1.96% 194
# https://business.abidjan.net/AL/a/94105.asp done!
# Completed: 2.29% 197
# https://business.abidjan.net/AL/a/94106.asp done!
# Completed: 2.61% 186
# https://business.abidjan.net/AL/a/94107.asp done!
# Completed: 2.94% 179
# https://business.abidjan.net/AL/a/94108.asp done!
# Completed: 3.27% 161
# https://business.abidjan.net/AL/a/94109.asp done!
# Completed: 3.59% 176
# https://business.abidjan.net/AL/a/94110.asp done!
# Completed: 3.92% 117
# https://business.abidjan.net/AL/a/94111.asp done!
# Completed: 4.25% 163
# https://business.abidjan.net/AL/a/94112.asp done!
# Completed: 4.58% 229
# https://business.abidjan.net/AL/a/94113.asp done!
# Completed: 4.90% 221
# https://business.abidjan.net/AL/a/94114.asp done!
# Completed: 5.23% 174
# https://business.abidjan.net/AL/a/94115.asp done!
# Completed: 5.56% 181
# https://business.abidjan.net/AL/a/94116.asp done!
# Completed: 5.88% 206
# https://business.abidjan.net/AL/a/94117.asp done!
# Completed: 6.21% 154
# https://business.abidjan.net/AL/a/94118.asp done!
# Completed: 6.54% 114
# https://business.abidjan.net/AL/a/94119.asp done!
# Completed: 6.86% 153
# https://business.abidjan.net/AL/a/94120.asp done!
# Completed: 7.19% 200
# https://business.abidjan.net/AL/a/94121.asp done!
# Completed: 7.52% 147
# https://business.abidjan.net/AL/a/94122.asp done!
# Completed: 7.84% 163
# https://business.abidjan.net/AL/a/94123.asp done!
# Completed: 8.17% 160
# https://business.abidjan.net/AL/a/94124.asp done!
# Completed: 8.50% 156
# https://business.abidjan.net/AL/a/94125.asp done!
# Completed: 8.82% 158
# https://business.abidjan.net/AL/a/94126.asp done!
# Completed: 9.15% 138
# https://business.abidjan.net/AL/a/94127.asp done!
# Completed: 9.48% 168
# https://business.abidjan.net/AL/a/94128.asp done!
# Completed: 9.80% 154
# https://business.abidjan.net/AL/a/94129.asp done!
# Completed: 10.13% 119
# https://business.abidjan.net/AL/a/94130.asp done!
# Completed: 10.46% 183
# https://business.abidjan.net/AL/a/94131.asp done!
# Completed: 10.78% 118
# https://business.abidjan.net/AL/a/94132.asp done!
# Completed: 11.11% 122
# https://business.abidjan.net/AL/a/94133.asp done!
# Completed: 11.44% 158
# https://business.abidjan.net/AL/a/94134.asp done!
# Completed: 11.76% 167
# https://business.abidjan.net/AL/a/94135.asp done!
# Completed: 12.09% 182
# https://business.abidjan.net/AL/a/94136.asp done!
# Completed: 12.42% 148
# https://business.abidjan.net/AL/a/94137.asp done!
# Completed: 12.75% 172
# https://business.abidjan.net/AL/a/94138.asp done!
# Completed: 13.07% 128
# https://business.abidjan.net/AL/a/94139.asp done!
# Completed: 13.40% 148
# https://business.abidjan.net/AL/a/94140.asp done!
# Completed: 13.73% 211
# https://business.abidjan.net/AL/a/94141.asp done!
# Completed: 14.05% 200
# https://business.abidjan.net/AL/a/94142.asp done!
# Completed: 14.38% 202
# https://business.abidjan.net/AL/a/94143.asp done!
# Completed: 14.71% 119
# https://business.abidjan.net/AL/a/94144.asp done!
# Completed: 15.03% 112
# https://business.abidjan.net/AL/a/94145.asp done!
# Completed: 15.36% 133
# https://business.abidjan.net/AL/a/94146.asp done!
# Completed: 15.69% 184
# https://business.abidjan.net/AL/a/94147.asp done!
# Completed: 16.01% 165
# https://business.abidjan.net/AL/a/94148.asp done!
# Completed: 16.34% 120
# https://business.abidjan.net/AL/a/94149.asp done!
# Completed: 16.67% 133
# https://business.abidjan.net/AL/a/94150.asp done!
# Completed: 16.99% 195
# https://business.abidjan.net/AL/a/94151.asp done!
# Completed: 17.32% 115
# https://business.abidjan.net/AL/a/94152.asp done!
# Completed: 17.65% 177
# https://business.abidjan.net/AL/a/94153.asp done!
# Completed: 17.97% 154
# https://business.abidjan.net/AL/a/94154.asp done!
# Completed: 18.30% 129
# https://business.abidjan.net/AL/a/94155.asp done!
# Completed: 18.63% 137
# https://business.abidjan.net/AL/a/94156.asp done!
# Completed: 18.95% 173
# https://business.abidjan.net/AL/a/94157.asp done!
# Completed: 19.28% 205
# https://business.abidjan.net/AL/a/94158.asp done!
# Completed: 19.61% 127
# https://business.abidjan.net/AL/a/94159.asp done!
# Completed: 19.93% 185
# https://business.abidjan.net/AL/a/94160.asp done!
# Completed: 20.26% 118
# https://business.abidjan.net/AL/a/94161.asp done!
# Completed: 20.59% 121
# https://business.abidjan.net/AL/a/94162.asp done!
# Completed: 20.92% 163
# https://business.abidjan.net/AL/a/94163.asp done!
# Completed: 21.24% 118
# https://business.abidjan.net/AL/a/94164.asp done!
# Completed: 21.57% 137
# https://business.abidjan.net/AL/a/94165.asp done!
# Completed: 21.90% 166
# https://business.abidjan.net/AL/a/94166.asp done!
# Completed: 22.22% 119
# https://business.abidjan.net/AL/a/94167.asp done!
# Completed: 22.55% 203
# https://business.abidjan.net/AL/a/94168.asp done!
# Completed: 22.88% 119
# https://business.abidjan.net/AL/a/94169.asp done!
# Completed: 23.20% 135
# https://business.abidjan.net/AL/a/94170.asp done!
# Completed: 23.53% 157
# https://business.abidjan.net/AL/a/94171.asp done!
# Completed: 23.86% 138
# https://business.abidjan.net/AL/a/94172.asp done!
# Completed: 24.18% 170
# https://business.abidjan.net/AL/a/94173.asp done!
# Completed: 24.51% 108
# https://business.abidjan.net/AL/a/94174.asp done!
# Completed: 24.84% 166
# https://business.abidjan.net/AL/a/94175.asp done!
# Completed: 25.16% 167
# https://business.abidjan.net/AL/a/94176.asp done!
# Completed: 25.49% 129
# https://business.abidjan.net/AL/a/94177.asp done!
# Completed: 25.82% 215
# https://business.abidjan.net/AL/a/94178.asp done!
# Completed: 26.14% 121
# https://business.abidjan.net/AL/a/94179.asp done!
# Completed: 26.47% 196
# https://business.abidjan.net/AL/a/94180.asp done!
# Completed: 26.80% 113
# https://business.abidjan.net/AL/a/94181.asp done!
# Completed: 27.12% 151
# https://business.abidjan.net/AL/a/94182.asp done!
# Completed: 27.45% 195
# https://business.abidjan.net/AL/a/94183.asp done!
# Completed: 27.78% 128
# https://business.abidjan.net/AL/a/94184.asp done!
# Completed: 28.10% 126
# https://business.abidjan.net/AL/a/94185.asp done!
# Completed: 28.43% 234
# https://business.abidjan.net/AL/a/94186.asp done!
# Completed: 28.76% 217
# https://business.abidjan.net/AL/a/94187.asp done!
# Completed: 29.08% 239
# https://business.abidjan.net/AL/a/94188.asp done!
# Completed: 29.41% 145
# https://business.abidjan.net/AL/a/94189.asp done!
# Completed: 29.74% 221
# https://business.abidjan.net/AL/a/94190.asp done!
# Completed: 30.07% 111
# https://business.abidjan.net/AL/a/94191.asp done!
# Completed: 30.39% 180
# https://business.abidjan.net/AL/a/94192.asp done!
# Completed: 30.72% 208
# https://business.abidjan.net/AL/a/94193.asp done!
# Completed: 31.05% 126
# https://business.abidjan.net/AL/a/94194.asp done!
# Completed: 31.37% 148
# https://business.abidjan.net/AL/a/94195.asp done!
# Completed: 31.70% 170
# https://business.abidjan.net/AL/a/94196.asp done!
# Completed: 32.03% 177
# https://business.abidjan.net/AL/a/94197.asp done!
# Completed: 32.35% 152
# https://business.abidjan.net/AL/a/94198.asp done!
# Completed: 32.68% 206
# https://business.abidjan.net/AL/a/94199.asp done!
# Completed: 33.01% 205
# https://business.abidjan.net/AL/a/94200.asp done!
# Completed: 33.33% 195
# https://business.abidjan.net/AL/a/94201.asp done!
# Completed: 33.66% 120
# https://business.abidjan.net/AL/a/94202.asp done!
# Completed: 33.99% 129
# https://business.abidjan.net/AL/a/94203.asp done!
# Completed: 34.31% 121
# https://business.abidjan.net/AL/a/94204.asp done!
# Completed: 34.64% 120
# https://business.abidjan.net/AL/a/94205.asp done!
# Completed: 34.97% 165
# https://business.abidjan.net/AL/a/94206.asp done!
# Completed: 35.29% 184
# https://business.abidjan.net/AL/a/94207.asp done!
# Completed: 35.62% 165
# https://business.abidjan.net/AL/a/94208.asp done!
# Completed: 35.95% 113
# https://business.abidjan.net/AL/a/94209.asp done!
# Completed: 36.27% 174
# https://business.abidjan.net/AL/a/94210.asp done!
# Completed: 36.60% 211
# https://business.abidjan.net/AL/a/94211.asp done!
# Completed: 36.93% 156
# https://business.abidjan.net/AL/a/94212.asp done!
# Completed: 37.25% 168
# https://business.abidjan.net/AL/a/94213.asp done!
# Completed: 37.58% 120
# https://business.abidjan.net/AL/a/94214.asp done!
# Completed: 37.91% 181
# https://business.abidjan.net/AL/a/94215.asp done!
# Completed: 38.24% 167
# https://business.abidjan.net/AL/a/94216.asp done!
# Completed: 38.56% 191
# https://business.abidjan.net/AL/a/94217.asp done!
# Completed: 38.89% 183
# https://business.abidjan.net/AL/a/94218.asp done!
# Completed: 39.22% 193
# https://business.abidjan.net/AL/a/94219.asp done!
# Completed: 39.54% 202
# https://business.abidjan.net/AL/a/94220.asp done!
# Completed: 39.87% 203
# https://business.abidjan.net/AL/a/94221.asp done!
# Completed: 40.20% 115
# https://business.abidjan.net/AL/a/94222.asp done!
# Completed: 40.52% 136
# https://business.abidjan.net/AL/a/94223.asp done!
# Completed: 40.85% 242
# https://business.abidjan.net/AL/a/94224.asp done!
# Completed: 41.18% 243
# https://business.abidjan.net/AL/a/94225.asp done!
# Completed: 41.50% 158
# https://business.abidjan.net/AL/a/94226.asp done!
# Completed: 41.83% 202
# https://business.abidjan.net/AL/a/94227.asp done!
# Completed: 42.16% 181
# https://business.abidjan.net/AL/a/94228.asp done!
# Completed: 42.48% 158
# https://business.abidjan.net/AL/a/94229.asp done!
# Completed: 42.81% 177
# https://business.abidjan.net/AL/a/94230.asp done!
# Completed: 43.14% 181
# https://business.abidjan.net/AL/a/94231.asp done!
# Completed: 43.46% 171
# https://business.abidjan.net/AL/a/94232.asp done!
# Completed: 43.79% 167
# https://business.abidjan.net/AL/a/94233.asp done!
# Completed: 44.12% 186
# https://business.abidjan.net/AL/a/94234.asp done!
# Completed: 44.44% 190
# https://business.abidjan.net/AL/a/94235.asp done!
# Completed: 44.77% 190
# https://business.abidjan.net/AL/a/94236.asp done!
# Completed: 45.10% 153
# https://business.abidjan.net/AL/a/94237.asp done!
# Completed: 45.42% 136
# https://business.abidjan.net/AL/a/94238.asp done!
# Completed: 45.75% 153
# https://business.abidjan.net/AL/a/94239.asp done!
# Completed: 46.08% 180
# https://business.abidjan.net/AL/a/94240.asp done!
# Completed: 46.41% 109
# https://business.abidjan.net/AL/a/94241.asp done!
# Completed: 46.73% 195
# https://business.abidjan.net/AL/a/94242.asp done!
# Completed: 47.06% 222
# https://business.abidjan.net/AL/a/94243.asp done!
# Completed: 47.39% 152
# https://business.abidjan.net/AL/a/94244.asp done!
# Completed: 47.71% 192
# https://business.abidjan.net/AL/a/94245.asp done!
# Completed: 48.04% 172
# https://business.abidjan.net/AL/a/94246.asp done!
# Completed: 48.37% 186
# https://business.abidjan.net/AL/a/94247.asp done!
# Completed: 48.69% 166
# https://business.abidjan.net/AL/a/94248.asp done!
# Completed: 49.02% 136
# https://business.abidjan.net/AL/a/94249.asp done!
# Completed: 49.35% 212
# https://business.abidjan.net/AL/a/94250.asp done!
# Completed: 49.67% 228
# https://business.abidjan.net/AL/a/94251.asp done!
# Completed: 50.00% 161
# https://business.abidjan.net/AL/a/94252.asp done!
# Completed: 50.33% 186
# https://business.abidjan.net/AL/a/94253.asp done!
# Completed: 50.65% 192
# https://business.abidjan.net/AL/a/94254.asp done!
# Completed: 50.98% 219
# https://business.abidjan.net/AL/a/94255.asp done!
# Completed: 51.31% 195
# https://business.abidjan.net/AL/a/94256.asp done!
# Completed: 51.63% 117
# https://business.abidjan.net/AL/a/94257.asp done!
# Completed: 51.96% 138
# https://business.abidjan.net/AL/a/94258.asp done!
# Completed: 52.29% 235
# https://business.abidjan.net/AL/a/94259.asp done!
# Completed: 52.61% 127
# https://business.abidjan.net/AL/a/94260.asp done!
# Completed: 52.94% 129
# https://business.abidjan.net/AL/a/94261.asp done!
# Completed: 53.27% 123
# https://business.abidjan.net/AL/a/94262.asp done!
# Completed: 53.59% 116
# https://business.abidjan.net/AL/a/94263.asp done!
# Completed: 53.92% 124
# https://business.abidjan.net/AL/a/94264.asp done!
# Completed: 54.25% 136
# https://business.abidjan.net/AL/a/94265.asp done!
# Completed: 54.58% 133
# https://business.abidjan.net/AL/a/94266.asp done!
# Completed: 54.90% 107
# https://business.abidjan.net/AL/a/94267.asp done!
# Completed: 55.23% 122
# https://business.abidjan.net/AL/a/94268.asp done!
# Completed: 55.56% 190
# https://business.abidjan.net/AL/a/94269.asp done!
# Completed: 55.88% 140
# https://business.abidjan.net/AL/a/94270.asp done!
# Completed: 56.21% 163
# https://business.abidjan.net/AL/a/94271.asp done!
# Completed: 56.54% 154
# https://business.abidjan.net/AL/a/94272.asp done!
# Completed: 56.86% 144
# https://business.abidjan.net/AL/a/94273.asp done!
# Completed: 57.19% 134
# https://business.abidjan.net/AL/a/94274.asp done!
# Completed: 57.52% 164
# https://business.abidjan.net/AL/a/94275.asp done!
# Completed: 57.84% 124
# https://business.abidjan.net/AL/a/94276.asp done!
# Completed: 58.17% 121
# https://business.abidjan.net/AL/a/94277.asp done!
# Completed: 58.50% 172
# https://business.abidjan.net/AL/a/94278.asp done!
# Completed: 58.82% 164
# https://business.abidjan.net/AL/a/94279.asp done!
# Completed: 59.15% 166
# https://business.abidjan.net/AL/a/94280.asp done!
# Completed: 59.48% 180
# https://business.abidjan.net/AL/a/94281.asp done!
# Completed: 59.80% 157
# https://business.abidjan.net/AL/a/94282.asp done!
# Completed: 60.13% 185
# https://business.abidjan.net/AL/a/94283.asp done!
# Completed: 60.46% 213
# https://business.abidjan.net/AL/a/94284.asp done!
# Completed: 60.78% 190
# https://business.abidjan.net/AL/a/94285.asp done!
# Completed: 61.11% 139
# https://business.abidjan.net/AL/a/94286.asp done!
# Completed: 61.44% 199
# https://business.abidjan.net/AL/a/94287.asp done!
# Completed: 61.76% 127
# https://business.abidjan.net/AL/a/94288.asp done!
# Completed: 62.09% 165
# https://business.abidjan.net/AL/a/94289.asp done!
# Completed: 62.42% 118
# https://business.abidjan.net/AL/a/94290.asp done!
# Completed: 62.75% 122
# https://business.abidjan.net/AL/a/94291.asp done!
# Completed: 63.07% 115
# https://business.abidjan.net/AL/a/94292.asp done!
# Completed: 63.40% 120
# https://business.abidjan.net/AL/a/94293.asp done!
# Completed: 63.73% 185
# https://business.abidjan.net/AL/a/94294.asp done!
# Completed: 64.05% 244
# https://business.abidjan.net/AL/a/94295.asp done!
# Completed: 64.38% 194
# https://business.abidjan.net/AL/a/94296.asp done!
# Completed: 64.71% 232
# https://business.abidjan.net/AL/a/94297.asp done!
# Completed: 65.03% 220
# https://business.abidjan.net/AL/a/94298.asp done!
# Completed: 65.36% 194
# https://business.abidjan.net/AL/a/94299.asp done!
# Completed: 65.69% 105
# https://business.abidjan.net/AL/a/94300.asp done!
# Completed: 66.01% 119
# https://business.abidjan.net/AL/a/94301.asp done!
# Completed: 66.34% 189
# https://business.abidjan.net/AL/a/94302.asp done!
# Completed: 66.67% 244
# https://business.abidjan.net/AL/a/94303.asp done!
# Completed: 66.99% 238
# https://business.abidjan.net/AL/a/94304.asp done!
# Completed: 67.32% 141
# https://business.abidjan.net/AL/a/94305.asp done!
# Completed: 67.65% 216
# https://business.abidjan.net/AL/a/94306.asp done!
# Completed: 67.97% 196
# https://business.abidjan.net/AL/a/94307.asp done!
# Completed: 68.30% 155
# https://business.abidjan.net/AL/a/94308.asp done!
# Completed: 68.63% 215
# https://business.abidjan.net/AL/a/94309.asp done!
# Completed: 68.95% 196
# https://business.abidjan.net/AL/a/94310.asp done!
# Completed: 69.28% 242
# https://business.abidjan.net/AL/a/94311.asp done!
# Completed: 69.61% 161
# https://business.abidjan.net/AL/a/94312.asp done!
# Completed: 69.93% 171
# https://business.abidjan.net/AL/a/94313.asp done!
# Completed: 70.26% 111
# https://business.abidjan.net/AL/a/94314.asp done!
# Completed: 70.59% 200
# https://business.abidjan.net/AL/a/94315.asp done!
# Completed: 70.92% 196
# https://business.abidjan.net/AL/a/94316.asp done!
# Completed: 71.24% 174
# https://business.abidjan.net/AL/a/94317.asp done!
# Completed: 71.57% 154
# https://business.abidjan.net/AL/a/94318.asp done!
# Completed: 71.90% 222
# https://business.abidjan.net/AL/a/94319.asp done!
# Completed: 72.22% 145
# https://business.abidjan.net/AL/a/94320.asp done!
# Completed: 72.55% 207
# https://business.abidjan.net/AL/a/94321.asp done!
# Completed: 72.88% 169
# https://business.abidjan.net/AL/a/94322.asp done!
# Completed: 73.20% 179
# https://business.abidjan.net/AL/a/94323.asp done!
# Completed: 73.53% 147
# https://business.abidjan.net/AL/a/94324.asp done!
# Completed: 73.86% 174
# https://business.abidjan.net/AL/a/94325.asp done!
# Completed: 74.18% 165
# https://business.abidjan.net/AL/a/94326.asp done!
# Completed: 74.51% 118
# https://business.abidjan.net/AL/a/94327.asp done!
# Completed: 74.84% 116
# https://business.abidjan.net/AL/a/94328.asp done!
# Completed: 75.16% 149
# https://business.abidjan.net/AL/a/94329.asp done!
# Completed: 75.49% 149
# https://business.abidjan.net/AL/a/94330.asp done!
# Completed: 75.82% 149
# https://business.abidjan.net/AL/a/94331.asp done!
# Completed: 76.14% 137
# https://business.abidjan.net/AL/a/94332.asp done!
# Completed: 76.47% 174
# https://business.abidjan.net/AL/a/94333.asp done!
# Completed: 76.80% 144
# https://business.abidjan.net/AL/a/94334.asp done!
# Completed: 77.12% 191
# https://business.abidjan.net/AL/a/94335.asp done!
# Completed: 77.45% 177
# https://business.abidjan.net/AL/a/94336.asp done!
# Completed: 77.78% 156
# https://business.abidjan.net/AL/a/94337.asp done!
# Completed: 78.10% 133
# https://business.abidjan.net/AL/a/94338.asp done!
# Completed: 78.43% 232
# https://business.abidjan.net/AL/a/94339.asp done!
# Completed: 78.76% 163
# https://business.abidjan.net/AL/a/94340.asp done!
# Completed: 79.08% 127
# https://business.abidjan.net/AL/a/94341.asp done!
# Completed: 79.41% 170
# https://business.abidjan.net/AL/a/94342.asp done!
# Completed: 79.74% 177
# https://business.abidjan.net/AL/a/94343.asp done!
# Completed: 80.07% 165
# https://business.abidjan.net/AL/a/94344.asp done!
# Completed: 80.39% 130
# https://business.abidjan.net/AL/a/94345.asp done!
# Completed: 80.72% 178
# https://business.abidjan.net/AL/a/94346.asp done!
# Completed: 81.05% 124
# https://business.abidjan.net/AL/a/94347.asp done!
# Completed: 81.37% 131
# https://business.abidjan.net/AL/a/94348.asp done!
# Completed: 81.70% 179
# https://business.abidjan.net/AL/a/94349.asp done!
# Completed: 82.03% 127
# https://business.abidjan.net/AL/a/94350.asp done!
# Completed: 82.35% 217
# https://business.abidjan.net/AL/a/94351.asp done!
# Completed: 82.68% 215
# https://business.abidjan.net/AL/a/94352.asp done!
# Completed: 83.01% 196
# https://business.abidjan.net/AL/a/94353.asp done!
# Completed: 83.33% 163
# https://business.abidjan.net/AL/a/94354.asp done!
# Completed: 83.66% 178
# https://business.abidjan.net/AL/a/94355.asp done!
# Completed: 83.99% 187
# https://business.abidjan.net/AL/a/94356.asp done!
# Completed: 84.31% 179
# https://business.abidjan.net/AL/a/94357.asp done!
# Completed: 84.64% 187
# https://business.abidjan.net/AL/a/94358.asp done!
# Completed: 84.97% 184
# https://business.abidjan.net/AL/a/94359.asp done!
# Completed: 85.29% 151
# https://business.abidjan.net/AL/a/94360.asp done!
# Completed: 85.62% 183
# https://business.abidjan.net/AL/a/94361.asp done!
# Completed: 85.95% 161
# https://business.abidjan.net/AL/a/94362.asp done!
# Completed: 86.27% 231
# https://business.abidjan.net/AL/a/94363.asp done!
# Completed: 86.60% 218
# https://business.abidjan.net/AL/a/94364.asp done!
# Completed: 86.93% 210
# https://business.abidjan.net/AL/a/94365.asp done!
# Completed: 87.25% 172
# https://business.abidjan.net/AL/a/94366.asp done!
# Completed: 87.58% 144
# https://business.abidjan.net/AL/a/94367.asp done!
# Completed: 87.91% 133
# https://business.abidjan.net/AL/a/94368.asp done!
# Completed: 88.24% 155
# https://business.abidjan.net/AL/a/94369.asp done!
# Completed: 88.56% 138
# https://business.abidjan.net/AL/a/94370.asp done!
# Completed: 88.89% 192
# https://business.abidjan.net/AL/a/94371.asp done!
# Completed: 89.22% 196
# https://business.abidjan.net/AL/a/94372.asp done!
# Completed: 89.54% 187
# https://business.abidjan.net/AL/a/94373.asp done!
# Completed: 89.87% 134
# https://business.abidjan.net/AL/a/94374.asp done!
# Completed: 90.20% 227
# https://business.abidjan.net/AL/a/94375.asp done!
# Completed: 90.52% 227
# https://business.abidjan.net/AL/a/94376.asp done!
# Completed: 90.85% 227
# https://business.abidjan.net/AL/a/94377.asp done!
# Completed: 91.18% 179
# https://business.abidjan.net/AL/a/94378.asp done!
# Completed: 91.50% 150
# https://business.abidjan.net/AL/a/94379.asp done!
# Completed: 91.83% 163
# https://business.abidjan.net/AL/a/94380.asp done!
# Completed: 92.16% 157
# https://business.abidjan.net/AL/a/94381.asp done!
# Completed: 92.48% 120
# https://business.abidjan.net/AL/a/94382.asp done!
# Completed: 92.81% 184
# https://business.abidjan.net/AL/a/94383.asp done!
# Completed: 93.14% 115
# https://business.abidjan.net/AL/a/94384.asp done!
# Completed: 93.46% 118
# https://business.abidjan.net/AL/a/94385.asp done!
# Completed: 93.79% 110
# https://business.abidjan.net/AL/a/94386.asp done!
# Completed: 94.12% 173
# https://business.abidjan.net/AL/a/94387.asp done!
# Completed: 94.44% 177
# https://business.abidjan.net/AL/a/94388.asp done!
# Completed: 94.77% 199
# https://business.abidjan.net/AL/a/94389.asp done!
# Completed: 95.10% 158
# https://business.abidjan.net/AL/a/94390.asp done!
# Completed: 95.42% 218
# https://business.abidjan.net/AL/a/94391.asp done!
# Completed: 95.75% 162
# https://business.abidjan.net/AL/a/94392.asp done!
# Completed: 96.08% 115
# https://business.abidjan.net/AL/a/94393.asp done!
# Completed: 96.41% 138
# https://business.abidjan.net/AL/a/94394.asp done!
# Completed: 96.73% 200
# https://business.abidjan.net/AL/a/94395.asp done!
# Completed: 97.06% 180
# https://business.abidjan.net/AL/a/94396.asp done!
# Completed: 97.39% 162
# https://business.abidjan.net/AL/a/94397.asp done!
# Completed: 97.71% 126
# https://business.abidjan.net/AL/a/94398.asp done!
# Completed: 98.04% 117
# https://business.abidjan.net/AL/a/94399.asp done!
# Completed: 98.37% 122
# https://business.abidjan.net/AL/a/94400.asp done!
# Completed: 98.69% 132
# https://business.abidjan.net/AL/a/94401.asp done!
# Completed: 99.02% 159
# https://business.abidjan.net/AL/a/94402.asp done!
# Completed: 99.35% 121
# https://business.abidjan.net/AL/a/94403.asp done!
# Completed: 99.67% 159
# https://business.abidjan.net/AL/a/94404.asp done!
# Completed: 100.00% 109
# https://business.abidjan.net/AL/a/94405.asp done!
# Completed: 100.33%
#                                           link                                       page-content
# 0  https://business.abidjan.net/AL/a/94100.asp  \n\n\nSociété :\n\nSAINT MICHEL IMMOBILIER «St...
# 1  https://business.abidjan.net/AL/a/94101.asp  \n\n\nSociété :\n\nSOCIETE COOPERATIVE SIMPLIF...
# 2  https://business.abidjan.net/AL/a/94102.asp  \n\n\nSociété :\n\nSCOOPS CPVD-SONGONKADI\n\n\...
# 3  https://business.abidjan.net/AL/a/94103.asp  \n\n\nSociété :\n\nSCOOPS EYEKOUN\n\n\n\nCatég...
# 4  https://business.abidjan.net/AL/a/94104.asp  \n\n\nSociété :\n\nENTREPRISE DE CHAUDRONNERIE...

# %% [markdown]
# ### Search fileds and return df

# %%
df_merged = search_fileds(df_merged)
df_merged.head()
# Out:
#                                           link  ...                                          siege
# 0  https://business.abidjan.net/AL/a/94100.asp  ...  abidjan - attinguie anyama eglise catholique,
# 1  https://business.abidjan.net/AL/a/94101.asp  ...
# 2  https://business.abidjan.net/AL/a/94102.asp  ...     est situe a abidjan - abobo (marche botou)
# 3  https://business.abidjan.net/AL/a/94103.asp  ...                     est situe a abidjan cocody
# 4  https://business.abidjan.net/AL/a/94104.asp  ...
#
# [5 rows x 16 columns]

# %% [markdown]
# ## Display missing fields in df

# %%
df_merged.isna().sum()
# Out:
# link              0
# page-content      0
# content           0
# email             0
# capital          71
# tel               0
# fax             240
# notaire           0
# categorie         0
# nom               0
# date              0
# rccm              1
# bp              123
# duree           234
# ville           116
# siege             0
# dtype: int64

# %% [markdown]
# #Update  your dataframe or save

# %%
#we load the data into df_merged1 and update it
path_to_df_1 = '/content/annonceDetail1.csv'#path_to_df_1 = 'Enter the path of your existing df'
df_merged1 = pd.read_csv(path_to_df_1, encoding='utf-16le' )
df_merged1.head()
# Out:
#                                       link  ...                                              siege
# 0  https://business.abidjan.net/AL/a/4.asp  ...         abidjan-cocody angre, 19 bp 174 abidjan 19
# 1  https://business.abidjan.net/AL/a/5.asp  ...  abidjan-treichville arras iii, 30 bp 566 abidj...
# 2  https://business.abidjan.net/AL/a/6.asp  ...                           abidjan commune dadjame
# 3  https://business.abidjan.net/AL/a/7.asp  ...                                                NaN
# 4  https://business.abidjan.net/AL/a/8.asp  ...           abidjan cocody riviera allabra, lot 189
#
# [5 rows x 14 columns]

# %%
df_merged_complete = pd.concat([df_merged1, df_merged],axis = 0)
df_merged_complete = df_merged_complete.reset_index()

# %%
type(stringlist)==list
# Out:
# True

# %% [markdown]
# * Transform list into values

# %%
def transform_list(stringlist):

  if type(stringlist)==list:
    chr = ''
    for x in stringlist:
      chr += x +'|'
    return chr
  return stringlist

for col in df_merged_complete.columns.tolist():
  df_merged_complete[col] = df_merged_complete[col].apply(lambda x:transform_list(x))

# %% [markdown]
# _*Pay attention to the path where you'll save the updated file*_

# %%
df_merged_complete = df_merged_complete.drop_duplicates()
path_to_save_df = '/content/annonceDetail_udate.csv'#path_to_save_df = 'write gere the absolute path of your new df'
df_merged_complete.to_csv(path_to_save_df, header=True, encoding='utf-16le', index =False )
